# %%
#Histograms
#Made up of vertical bars that track frequency of data 

import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
body_data = pd.read_csv("weights_and_heights.csv")

# %%
body_data
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
body_data.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
body_data.value_counts()
# Out:
# Gender  Height     Weight
# Female  54.263133  64.700127     1
# Male    67.830001  172.776569    1
#         67.809015  179.934465    1
#         67.810251  170.457826    1
#         67.814286  192.066392    1
#                                 ..
# Female  64.854997  146.692798    1
#         64.855262  150.397118    1
#         64.859973  140.784838    1
#         64.860659  159.568225    1
# Male    78.998742  269.989699    1
# Name: count, Length: 10000, dtype: int64

# %%
body_data.shape
# Out:
# (10000, 3)

# %%
#Split data frames

male = body_data[body_data["Gender"] == "Male"]
female = body_data[body_data["Gender"] == "Female"]

# %%
#Historgram for males
plt.style.use("seaborn-poster")
plt.hist(male["Weight"])
plt.show()
# Out:
# C:\Users\19144\AppData\Local\Temp\ipykernel_32172\1998282565.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-poster")

# %%
#We can split into further bins
#Bins by default is set by 10s
#More bins can demonstrate whether data is evenly distributed
#Historgram for males
plt.style.use("seaborn-poster")
plt.hist(male["Weight"], bins = 20, edgecolor = "black")
plt.show()
# Out:
# C:\Users\19144\AppData\Local\Temp\ipykernel_32172\2268887467.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-poster")

# %%
#Males and females
plt.style.use("seaborn-poster")
plt.hist(male["Weight"], bins = 20, edgecolor = "black")
plt.hist(female["Weight"], bins = 20, edgecolor = "black")
plt.show()
# Out:
# C:\Users\19144\AppData\Local\Temp\ipykernel_32172\1482583585.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-poster")

# %%
#It can be difficult to see where the overlap is here
#Female plotted second - plotted right on top of male
#We can fix this with alpha parameter - allows control over transparency over plot = 1 - full color, toward 0 more transparent
#Males and females
plt.style.use("seaborn-poster")
plt.hist(male["Weight"], bins = 20, edgecolor = "black", alpha = 0.6)
plt.hist(female["Weight"], bins = 20, edgecolor = "black", alpha = 0.6)
plt.show()
# Out:
# C:\Users\19144\AppData\Local\Temp\ipykernel_32172\3352047430.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-poster")

# %%
#Males and females
plt.style.use("seaborn-poster")
plt.hist(male["Weight"], bins = 20, edgecolor = "black", alpha = 0.6, color = "royalblue", label = "Male")
plt.hist(female["Weight"], bins = 20, edgecolor = "black", alpha = 0.6, color = "magenta", label = "Female")
plt.title("Distribution of Body Weight by Gender")
plt.xlabel("Weight (lbs)")
plt.ylabel("Frequency")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\19144\AppData\Local\Temp\ipykernel_32172\1976553723.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-poster")
